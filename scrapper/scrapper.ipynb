# %%
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
import json

# %% [markdown]
# - Pega conteúdo HTML apartir da URL

# %%
url = "https://www.nba.com/stats/players/traditional?dir=A&sort=PTS"

# instanciar o firefox
option = Options()
option.headless = True
driver = webdriver.Chrome()

driver.get(url)
time.sleep(10)

driver.quit()
# Out:
# /tmp/ipykernel_1018/3333376771.py:5: DeprecationWarning: headless property is deprecated, instead use add_argument('-headless')
#   option.headless = True
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[21], line 6
#       4 option = Options()
#       5 option.headless = True
# ----> 6 driver = webdriver.Chrome()
#       8 driver.get(url)
#       9 time.sleep(10)
#
# File /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py:80, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      77 if not service:
#      78     service = Service(executable_path, port, service_args, service_log_path)
# ---> 80 super().__init__(
#      81     DesiredCapabilities.CHROME["browserName"],
#      82     "goog",
#      83     port,
#      84     options,
#      85     service_args,
#      86     desired_capabilities,
#      87     service_log_path,
#      88     service,
#      89     keep_alive,
#      90 )
#
# File /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py:101, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      98     raise AttributeError("service cannot be None")
#     100 self.service = service
# --> 101 self.service.start()
#     103 try:
#     104     super().__init__(
#     105         command_executor=ChromiumRemoteConnection(
#     106             remote_server_addr=self.service.service_url,
#    (...)
#     112         options=options,
#     113     )
#
# File /usr/local/lib/python3.10/dist-packages/selenium/webdriver/common/service.py:106, in Service.start(self)
#     104 count = 0
#     105 while True:
# --> 106     self.assert_process_still_running()
#     107     if self.is_connectable():
#     108         break
#
# File /usr/local/lib/python3.10/dist-packages/selenium/webdriver/common/service.py:119, in Service.assert_process_still_running(self)
#     117 return_code = self.process.poll()
#     118 if return_code:
# --> 119     raise WebDriverException(f"Service {self.path} unexpectedly exited. Status code was: {return_code}")
#
# WebDriverException: Message: Service chromedriver unexpectedly exited. Status code was: 127

# %% [markdown]
# Parsear o conteúdo HTML
